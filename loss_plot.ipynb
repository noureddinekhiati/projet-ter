# %%
from loss_function import plot_loss
from matplotlib import pyplot as plt

# %%
gan,gl1,dfake,dreal = plot_loss()
# Out:
# [0, 1.329, 49.17, 0.772, 0.33, 2.237, 51.7, 0.233, 0.262, 2.488, 33.64, 0.056, 0.211, 4.134, 48.33, 0.053, 0.425, 4.556, 53.66, 0.191, 0.01, 1.569, 30.09, 0.479, 0.376, 1.78, 46.83, 0.01, 0.436, 2.536, 50.85, 0.04, 0.247, 2.306, 36.83, 0.1, 0.067, 1.529, 32.1, 0.827, 0.925, 3.272, 35.97, 0.061, 0.061, 4.502, 46.52, 0.015, 0.021, 4.026, 30.14, 0.314, 0.044, 2.952, 25.69, 0.1, 0.084, 3.37, 30.88, 0.03, 0.044, 3.442, 29.32, 0.157, 0.044, 3.423, 47.7, 0.512, 0.035, 2.87, 32.42, 0.645, 0.027, 3.877, 43.25, 0.033, 0.02, 3.034, 59.94, 0.001, 0.103, 2.806, 27.42, 0.013, 0.115, 1.22, 15.13, 0.543, 0.825, 1.833, 33.82, 3.339, 0.03, 4.536, 29.09, 1.196, 0.008, 3.529, 33.79, 0.059, 0.05, 2.378, 37.39, 0.385, 0.089, 4.81, 33.41, 0.834, 0.005, 2.144, 37.54, 0.235, 0.184, 3.023, 18.69, 0.537, 0.048, 1.225, 20.45, 2.104, 0.046, 2.32, 76.06, 0.0, 0.345, 2.055, 22.45, 0.179, 0.516, 2.529, 36.37, 0.002, 0.319, 1.256, 24.19, 0.427, 0.31, 2.958, 25.01, 2.098, 0.016, 3.635, 25.77, 2.198, 0.004, 2.686, 29.
# ...

# %%
plt.plot(gan)

# %%
plt.plot(gl1)
